# %% [markdown]
# ## the Breast Cancer dataset and the reasons behinde it as another dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')

# %matplotlib inline

# %%
#importing dataset
df1 = pd.read_csv("data.csv")

# %%
#importing dataset
df2 = pd.read_csv("Breast Cancer METABRIC.csv")

# %%
df = pd.concat([df1,df2], axis=0)
##df = df.rename(columns={"Unnamed: 1": "weekday"})
##df = df.dropna(subset=["weekday"])
df.head()
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302.0         M        17.99         10.38          122.80     1001.0
# 1    842517.0         M        20.57         17.77          132.90     1326.0
# 2  84300903.0         M        19.69         21.25          130.00     1203.0
# 3  84348301.0         M        11.42         20.38           77.58      386.1
# 4  84358402.0         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (3078, 67)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32',
#        'Patient ID', 'Age at Diagnosis', 'Type of Breast Surgery',
#        'Cancer Type', 'Cancer Type Detailed', 'Cellularity', 'Chemotherapy',
#        'Pam50 + Claudin-low subtype', 'Cohort', 'ER status measured by IHC',
#        'ER Status', 'Neoplasm Histologic Grade',
#        'HER2 status measured by SNP6', 'HER2 Status',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3078 entries, 0 to 2508
# Data columns (total 67 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              569 non-null    float64
#  1   diagnosis                       569 non-null    object
#  2   radius_mean                     569 non-null    float64
#  3   texture_mean                    569 non-null    float64
#  4   perimeter_mean                  569 non-null    float64
#  5   area_mean                       569 non-null    float64
#  6   smoothness_mean                 569 non-null    float64
#  7   compactness_mean                569 non-null    float64
#  8   concavity_mean                  569 non-null    float64
#  9   concave points_mean             569 non-null    float64
#  10  symmetry_mean                   569 non-null    float64
#  11  fractal_dimension_mean          569 non-null    float64
# ...

# %%
df.shape
# Out:
# (3078, 67)

# %%
plt.figure(figsize = (20, 10))
matrix = np.triu(df.corr())
sb.heatmap(df.corr(), annot = True, linewidth = 0.9, mask = matrix, cmap = "BrBG")
# Out:
# <AxesSubplot:>

# %%
#Second method: plotting using barplot
x = df['diagnosis'].value_counts().index
y = df['diagnosis'].value_counts().values

plt.figure(figsize=(9,6))
ax= sns.barplot(x, y,data= df ,alpha=0.8 )
plt.title("Cancer results")
plt.xlabel('', fontsize=12);
# Out:
# C:\Users\itsma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(f'METABRIC Dataset Shape: {df.shape}')
print(f'METABRIC Dataset Memory Usage: {df.memory_usage().sum() / 1024 ** 2:.2f} MB')
# Out:
# METABRIC Dataset Shape: (3078, 67)
# METABRIC Dataset Memory Usage: 1.60 MB

# %% [markdown]
# ## Conculsion

# %% [markdown]
# ### The graph show the number  b that  stands for benign and the m stands for malignant and the benign is more than the malignant. and it seems to grow more. B is about 350 and M is about 210
